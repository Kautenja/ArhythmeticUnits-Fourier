# %% [markdown]
# # Blackman Window
#
# $$
# w[n] = 0.42 - 0.5\cos\Big(\frac{2 \pi n}{N - \mathrm{1}_{symmetric}}\Big)
# + 0.08\cos\Big(\frac{4 \pi n}{N - \mathrm{1}_{symmetric}}\Big)
# $$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal as dsp
from scipy import fft
import IPython.display as display
from zplot import zplot
from compare import compare

# %%
def blackman(N, sym=False):
    """
    Return a Blackman window.

    Args:
        N: Number of points in the output window. 
        If zero or less, an empty array is returned.
        sym: When True (default), generates a symmetric window, 
        for use in filter design. When False, generates a 
        periodic window, for use in spectral analysis.

    Returns:
        the Blackman window of length N with given symmetry

    """
    n = np.arange(N)
    N = N - 1 if sym else N
    return 0.42 - 0.50 * np.cos(2 * np.pi * n / N) + 0.08 * np.cos(4 * np.pi * n / N)

# %% [markdown]
# ## Asymmetric

# %% [markdown]
# ### Odd

# %%
test, reference = compare(7, blackman, dsp.blackman, False)

# %%
_ = dsp.freqz(test, plot=zplot)

# %%
list(test)
# Out:
# [-1.3877787807814457e-17,
#  0.09045342435412804,
#  0.45918295754596355,
#  0.9203636180999081,
#  0.9203636180999083,
#  0.45918295754596383,
#  0.09045342435412812]

# %%
list(reference)
# Out:
# [-1.3877787807814457e-17,
#  0.09045342435412813,
#  0.45918295754596367,
#  0.9203636180999082,
#  0.9203636180999082,
#  0.45918295754596367,
#  0.09045342435412813]

# %% [markdown]
# ### Even

# %%
test, reference = compare(8, blackman, dsp.blackman, False)

# %%
_ = dsp.freqz(test, plot=zplot)

# %%
list(test)
# Out:
# [-1.3877787807814457e-17,
#  0.0664466094067262,
#  0.3399999999999999,
#  0.7735533905932737,
#  0.9999999999999999,
#  0.7735533905932739,
#  0.3400000000000001,
#  0.06644660940672623]

# %%
list(reference)
# Out:
# [-1.3877787807814457e-17,
#  0.06644660940672624,
#  0.34,
#  0.7735533905932738,
#  0.9999999999999999,
#  0.7735533905932738,
#  0.34,
#  0.06644660940672624]

# %% [markdown]
# ## Symmetric

# %% [markdown]
# ### Odd

# %%
test, reference = compare(7, blackman, dsp.blackman, True)

# %%
_ = dsp.freqz(test, plot=zplot)

# %%
list(test)
# Out:
# [-1.3877787807814457e-17,
#  0.12999999999999995,
#  0.6299999999999999,
#  0.9999999999999999,
#  0.6300000000000002,
#  0.13,
#  -1.3877787807814457e-17]

# %%
list(reference)
# Out:
# [-1.3877787807814457e-17,
#  0.12999999999999995,
#  0.6299999999999999,
#  0.9999999999999999,
#  0.6300000000000002,
#  0.1300000000000002,
#  -1.3877787807814457e-17]

# %% [markdown]
# ### Even

# %%
test, reference = compare(8, blackman, dsp.blackman, True)

# %%
_ = dsp.freqz(test, plot=zplot)

# %%
list(test)
# Out:
# [-1.3877787807814457e-17,
#  0.09045342435412804,
#  0.45918295754596355,
#  0.9203636180999081,
#  0.9203636180999083,
#  0.45918295754596383,
#  0.09045342435412812,
#  -1.3877787807814457e-17]

# %%
list(reference)
# Out:
# [-1.3877787807814457e-17,
#  0.09045342435412813,
#  0.45918295754596367,
#  0.9203636180999082,
#  0.9203636180999082,
#  0.45918295754596367,
#  0.09045342435412813,
#  -1.3877787807814457e-17]

# %% [markdown]
# ## Coherent Gain

# %%
blackman(1024, False).mean()
# Out:
# 0.42

# %% [markdown]
# ## Side-lobe amplitude

# %%
w = blackman(31, False)
w = np.pad(w, (512, 512))
H = fft.fft(w)
H = fft.fftshift(H)
H = 20 * np.log10(np.abs(H) + 1e-12)
H = H - H.max()
peaks, _ = dsp.find_peaks(H)
ymin = H[peaks[len(peaks)//2:]][-1] - 1
plt.figure(figsize=(15, 5))
plt.plot(H)
for x, y in zip(peaks, H[peaks]):
    if y > ymin:
        plt.text(x, y, f'{y:.2f}')
plt.ylabel('H[k] (dB)')
plt.xlabel('h[n]')
plt.ylim(ymin - 1, 1)
sorted(H[peaks], reverse=True)[1]
# Out:
# -58.137667801010146
